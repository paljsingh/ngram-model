# %%
import nltk
from nltk.tokenize import RegexpTokenizer
import json
import re
from collections import defaultdict
import requests
import html

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jitender.singh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
class SEAnswers:
    """
    fetches questions and answers from stack exchange sites.
    """

    sites = {
        'stackoverflow': {
            'api_url': 'https://api.stackexchange.com/2.3',
            'questions_api': '/questions',
            'question_args': '?site={site}&tagged={tag}&sort={sort_by}&order={sort_order}&page={page_id}',
            'answers_api': '/questions/{question_ids}/answers',
            'answers_args': '?site={site}&filter=withbody',
        },
    }

    def __init__(self, site_name='stackoverflow'):
        self.site_name = site_name

    # https://api.stackexchange.com/2.3/questions?page=1&order=desc&sort=votes&tagged=nlp&site=stackoverflow
    def get_question_ids(self, tag='nlp', sort_by='votes', sort_order='desc', page_id=1):

        site = self.sites[self.site_name]
        question_args = site['question_args'].format(
            site=self.site_name, tag=tag, sort_by=sort_by, sort_order=sort_order, page_id=page_id)

        url = '{api_url}{questions_api}{question_args}'.format(
            api_url=site['api_url'],
            questions_api=site['questions_api'],
            question_args=question_args,
        )
        print(url)

        response = requests.get(url)
        question_ids = []
        if response.status_code == 200:
            json_response = response.json()
            for item in json_response['items']:
                if item.get('is_answered') and item.get('answer_count') > 0:
                    question_ids.append(item.get('question_id'))
        return question_ids

    def get_answers(self, question_ids):
        site = self.sites[self.site_name]
        qid_str = ';'.join([str(x) for x in question_ids])
        answers_api = site['answers_api'].format(question_ids=qid_str)
        answers_args = site['answers_args'].format(site=self.site_name)

        url = '{api_url}{answers_api}{answers_args}'.format(
            api_url=site['api_url'],
            answers_api=answers_api,
            answers_args=answers_args,
        )
        print(url)

        response = requests.get(url)
        answers = []
        if response.status_code == 200:
            json_response = response.json()
            for item in json_response['items']:
                if item.get('body'):
                    answers.append(item['body'])

        return answers


class WordCounter:

    def __init__(self):
        self.words = defaultdict(lambda: 0)
        self.word_tokenizer = RegexpTokenizer(r'\w+')

    def clean_html_tags(self, html_text):
        pattern = re.compile('<.*?>')
        return re.sub(pattern, '', html_text)

    def count_words(self, answers):
        answers_html_str = ' '.join(answers)

        # clean html tags first.
        answers_str = self.clean_html_tags(answers_html_str)
        answers_str = html.unescape(answers_str)
        word_tokens = self.word_tokenizer.tokenize(answers_str)
        for word_token in word_tokens:
            if word_token:
                # convert all tokens to lowercase and count frequency
                self.words[word_token.lower()] += 1

    def get_words(self, min_frequency=1):
        word_dict = dict()
        for word, frequency in self.words.items():
            if frequency >= min_frequency:
                word_dict[word] = frequency
        return word_dict


se = SEAnswers()
wc = WordCounter()

qids = se.get_question_ids(tag='nlp')
answers = se.get_answers(qids)

wc.count_words(answers)
print(sorted(wc.get_words(min_frequency=1).items(), key=lambda x: x[1], reverse=True))
# Out:
# https://api.stackexchange.com/2.3/questions?site=stackoverflow&tagged=nlp&sort=votes&order=desc&page=1
# https://api.stackexchange.com/2.3/questions/307291;8897593;1833252;34870614;1787110;405161;15547409;9294926;31421413;10401076;22904025;41424;771918;27860652;1288291;10850997;13883277;870460;3522372;27697766;573768;51956000;4951751;19130512;526469;15173225;10554052;17317418;10383044;9706769/answers?site=stackoverflow&filter=withbody
# [('the', 237), ('a', 125), ('to', 110), ('is', 104), ('and', 103), ('in', 101), ('of', 100), ('you', 93), ('for', 74), ('it', 74), ('words', 73), ('i', 62), ('word', 58), ('if', 58), ('as', 56), ('1', 55), ('that', 54), ('n', 54), ('this', 52), ('can', 49), ('are', 46), ('t', 41), ('be', 40), ('s', 40), ('or', 39), ('with', 37), ('my', 36), ('from', 35), ('c', 34), ('an', 32), ('0', 30), ('similarity', 29), ('2', 29), ('there', 28), ('have', 27), ('syllables', 27), ('x', 27), ('would', 26), ('on', 26), ('not', 26), ('by', 24), ('use', 24), ('return', 24), ('import', 24), ('we', 24), ('str', 24), ('text', 23), ('which', 23), ('all', 22), ('more', 21), ('char', 21), ('stemming', 20), ('do', 20), ('3', 20), ('some', 20), ('here', 19), ('ll', 19), ('your', 18), ('between', 18), ('other', 18), ('than', 18), ('very', 18), ('string', 18), ('but', 18), ('d', 17), ('re', 17), ('sentence', 16), ('noun', 16), ('should', 16), ('then', 16), ('also', 16), ('nltk', 16), ('want', 15), ('lemmatization', 15), ('context', 15), ('one', 15), ('what', 15), ('else', 15), ('https', 14), ('just', 14), ('e', 14), ('spacy', 14), ('how', 14), ('set', 14), ('most', 14), ('so', 14), ('go', 14), ('com', 13), ('g', 13), ('python', 13), ('m', 13), ('two', 13), ('may', 13), ('ve', 13), ('same', 13), ('they', 13), ('will', 13), ('find', 13), ('sentences', 13), ('snowball', 13), ('into', 12), ('found', 12), ('w', 12), ('many', 12), ('print', 12), ('english', 12), ('like', 12), ('see', 12), ('porter', 12), ('vowels', 12), ('stem', 11), ('language', 11), ('vectors', 11), ('at', 11), ('result', 11), ('pip', 11), ('nlp', 11), ('list', 11), ('corpus', 11), ('first', 11), ('tf', 11), ('v', 11), ('df', 11), ('4', 11), ('verb', 10), ('their', 10), ('when', 10), ('similar', 10), ('install', 10), ('code', 10), ('values', 10), ('value', 10), ('its', 10), ('these', 10), ('y', 10), ('get', 10), ('need', 10), ('well', 10), ('tag', 10), ('vowel', 10), ('paste0', 10), ('vec1', 10), ('vec2', 10), ('softmax', 10), ('based', 9), ('denominator', 9), ('negative', 9), ('download', 9), ('good', 9), ('any', 9), ('few', 9), ('such', 9), ('where', 9), ('j', 9), ('part', 9), ('r', 9), ('since', 9), ('take', 9), ('used', 9), ('using', 9), ('ax', 9), ('cosine', 9), ('model', 9), ('algorithm', 9), ('txt', 9), ('len', 9), ('includes', 9), ('time', 9), ('parse', 8), ('http', 8), ('might', 8), ('much', 8), ('def', 8), ('keep', 8), ('has', 8), ('out', 8), ('over', 8), ('too', 8), ('etc', 8), ('run', 8), ('th', 8), ('6', 8), ('start', 8), ('called', 8), ('lemmatize', 8), ('function', 8), ('previous', 8), ('data', 8), ('category', 8), ('keys', 8), ('each', 7), ('stemmers', 7), ('end', 7), ('could', 7), ('about', 7), ('frequency', 7), ('while', 7), ('form', 7), ('stopwords', 7), ('them', 7), ('those', 7), ('done', 7), ('less', 7), ('sometimes', 7), ('u', 7), ('without', 7), ('speech', 7), ('vec', 7), ('sum', 7), ('hyphen', 7), ('path', 7), ('labels', 7), ('seconds', 7), ('phrases', 6), ('way', 6), ('really', 6), ('always', 6), ('morphological', 6), ('algorithms', 6), ('often', 6), ('apply', 6), ('lemma', 6), ('was', 6), ('together', 6), ('ci', 6), ('however', 6), ('because', 6), ('sampling', 6), ('vector', 6), ('several', 6), ('instead', 6), ('f', 6), ('following', 6), ('better', 6), ('three', 6), ('yet', 6), ('he', 6), ('only', 6), ('our', 6), ('own', 6), ('she', 6), ('who', 6), ('different', 6), ('enough', 6), ('last', 6), ('ng', 6), ('results', 6), ('something', 6), ('though', 6), ('usually', 6), ('whether', 6), ('www', 6), ('ch', 6), ('documents', 6), ('large', 6), ('prefix', 6), ('count', 6), ('fre', 6), ('fkgl', 6), ('meaning', 6), ('lancaster', 6), ('languages', 6), ('3547', 6), ('913', 6), ('math', 6), ('text_to_vector', 6), ('hub', 6), ('constituency', 5), ('tree', 5), ('non', 5), ('simple', 5), ('bill', 5), ('dependency', 5), ('within', 5), ('give', 5), ('org', 5), ('base', 5), ('word2vec', 5), ('numerator', 5), ('problem', 5), ('faster', 5), ('train', 5), ('after', 5), ('token', 5), ('ma ...

# %% [markdown]
# The above shows word count for stackoverflow answers with questions tagged with 'nlp'

# %%
qids = se.get_question_ids(tag='java')
answers = se.get_answers(qids)

wc = WordCounter()
wc.count_words(answers)
print(sorted(wc.get_words(min_frequency=1).items(), key=lambda x: x[1], reverse=True))
# Out:
# https://api.stackexchange.com/2.3/questions?site=stackoverflow&tagged=java&sort=votes&order=desc&page=1
# https://api.stackexchange.com/2.3/questions/11227809;6841333;40480;309424;271526;40471;157944;13375357;363681;8710619;8881291;46898;1066589;6470651;215497;322715;5585779;285793;1005073;34571;21947452;574594;6343166;65035;1128723;285177;37628;6827752;1200621;541487/answers?site=stackoverflow&filter=withbody
# [('the', 303), ('is', 149), ('to', 120), ('a', 99), ('and', 79), ('of', 79), ('in', 75), ('you', 69), ('it', 63), ('if', 60), ('t', 60), ('value', 54), ('this', 53), ('for', 43), ('hashmap', 40), ('hashtable', 40), ('that', 40), ('be', 37), ('java', 37), ('string', 37), ('data', 37), ('s', 37), ('object', 35), ('can', 35), ('i', 35), ('dog', 34), ('system', 33), ('will', 31), ('public', 30), ('method', 30), ('not', 29), ('by', 28), ('are', 28), ('as', 27), ('branch', 27), ('new', 26), ('out', 26), ('map', 26), ('foo', 26), ('println', 24), ('return', 24), ('code', 23), ('null', 23), ('an', 22), ('class', 22), ('with', 22), ('from', 22), ('then', 21), ('0', 21), ('array', 21), ('at', 20), ('1', 20), ('int', 20), ('key', 19), ('memory', 19), ('contains', 19), ('when', 18), ('or', 18), ('on', 18), ('size', 18), ('adog', 18), ('static', 17), ('there', 17), ('arrays', 17), ('c', 17), ('we', 16), ('void', 16), ('one', 16), ('values', 16), ('but', 16), ('which', 15), ('equals', 15), ('2', 15), ('random', 15), ('true', 15), ('list', 15), ('observer', 15), ('entry', 14), ('so', 14), ('have', 14), ('aslist', 14), ('reference', 14), ('change', 14), ('d', 14), ('has', 13), ('test', 13), ('synchronized', 13), ('other', 13), ('example', 13), ('stack', 13), ('address', 13), ('max', 12), ('param', 12), ('file', 12), ('time', 12), ('what', 12), ('start', 12), ('sorted', 12), ('n', 12), ('fifi', 12), ('ts', 12), ('put', 11), ('thread', 11), ('many', 11), ('any', 11), ('objects', 11), ('pass', 11), ('set', 11), ('safe', 10), ('3', 10), ('way', 10), ('like', 10), ('references', 10), ('no', 10), ('given', 10), ('elements', 10), ('using', 9), ('name', 9), ('integer', 9), ('m', 9), ('between', 9), ('use', 9), ('case', 9), ('they', 9), ('guess', 9), ('somedog', 9), ('final', 9), ('search', 9), ('observers', 9), ('main', 8), ('same', 8), ('leak', 8), ('still', 8), ('x', 8), ('interface', 8), ('train', 8), ('more', 8), ('mydog', 8), ('getname', 8), ('hash', 7), ('index', 7), ('import', 7), ('non', 7), ('doesn', 7), ('do', 7), ('sort', 7), ('check', 7), ('arraylist', 7), ('element', 7), ('where', 7), ('means', 7), ('were', 7), ('go', 7), ('direction', 7), ('would', 7), ('fast', 7), ('pointer', 7), ('line', 7), ('searched', 7), ('scanner', 7), ('indexof', 7), ('collections', 7), ('collection', 7), ('obsolete', 7), ('used', 6), ('util', 6), ('ht', 6), ('hm', 6), ('threads', 6), ('synchronization', 6), ('since', 6), ('was', 6), ('constructor', 6), ('calling', 6), ('two', 6), ('call', 6), ('could', 6), ('back', 6), ('just', 6), ('optional', 6), ('returns', 6), ('otherwise', 6), ('present', 6), ('consumer', 6), ('also', 6), ('while', 6), ('does', 6), ('shortcut', 6), ('here', 6), ('down', 6), ('need', 6), ('pattern', 6), ('above', 6), ('because', 6), ('than', 6), ('some', 6), ('42', 6), ('variable', 6), ('passed', 6), ('strings', 6), ('currenttimemillis', 6), ('iterator', 6), ('private', 6), ('table', 5), ('args', 5), ('101', 5), ('entryset', 5), ('getkey', 5), ('getvalue', 5), ('allows', 5), ('methods', 5), ('created', 5), ('how', 5), ('always', 5), ('good', 5), ('such', 5), ('false', 5), ('finally', 5), ('primitive', 5), ('type', 5), ('inside', 5), ('suppose', 5), ('abc', 5), ('desktop', 5), ('fail', 5), ('stop', 5), ('up', 5), ('path', 5), ('never', 5), ('often', 5), ('statement', 5), ('goes', 5), ('even', 5), ('note', 5), ('branching', 5), ('branchless', 5), ('update', 5), ('8', 5), ('them', 5), ('structurally', 5), ('store', 4), ('stored', 4), ('within', 4), ('only', 4), ('test1', 4), ('102', 4), ('test2', 4), ('test3', 4), ('shared', 4), ('whereas', 4), ('allow', 4), ('over', 4), ('implement', 4), ('these', 4), ('called', 4), ('done', 4), ('generate', 4), ('should', 4), ('its', 4), ('times', 4), ('e', 4), ('may', 4), ('slow', 4), ('follow', 4), ('boolean', 4), ('before', 4), ('try', 4), ('let', 4), ('first', 4), ('make', 4), ('original', 4), ('actually', 4), ('better', 4), ('lot', 4), ('guessed', 4), ('right', 4), ('wrong', 4), ('see', 4), ('your', 4), ...

# %% [markdown]
# The above shows word count for stackoverflow answers with questions tagged with 'java'
