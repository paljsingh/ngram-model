# %%
import nltk
from nltk.corpus import brown
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize import RegexpTokenizer

# %%
nltk.download('brown')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/jitender.singh/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jitender.singh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jitender.singh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
"""
print the file ids. (first 100)
"""
print(nltk.corpus.brown.fileids()[:100])
# Out:
# ['ca01', 'ca02', 'ca03', 'ca04', 'ca05', 'ca06', 'ca07', 'ca08', 'ca09', 'ca10', 'ca11', 'ca12', 'ca13', 'ca14', 'ca15', 'ca16', 'ca17', 'ca18', 'ca19', 'ca20', 'ca21', 'ca22', 'ca23', 'ca24', 'ca25', 'ca26', 'ca27', 'ca28', 'ca29', 'ca30', 'ca31', 'ca32', 'ca33', 'ca34', 'ca35', 'ca36', 'ca37', 'ca38', 'ca39', 'ca40', 'ca41', 'ca42', 'ca43', 'ca44', 'cb01', 'cb02', 'cb03', 'cb04', 'cb05', 'cb06', 'cb07', 'cb08', 'cb09', 'cb10', 'cb11', 'cb12', 'cb13', 'cb14', 'cb15', 'cb16', 'cb17', 'cb18', 'cb19', 'cb20', 'cb21', 'cb22', 'cb23', 'cb24', 'cb25', 'cb26', 'cb27', 'cc01', 'cc02', 'cc03', 'cc04', 'cc05', 'cc06', 'cc07', 'cc08', 'cc09', 'cc10', 'cc11', 'cc12', 'cc13', 'cc14', 'cc15', 'cc16', 'cc17', 'cd01', 'cd02', 'cd03', 'cd04', 'cd05', 'cd06', 'cd07', 'cd08', 'cd09', 'cd10', 'cd11', 'cd12']

# %%
"""
Reading a sample file, and print words (first 100)
"""
print(nltk.corpus.brown.words('cr09')[:100])
# Out:
# ['Dear', 'Sirs', ':', 'Let', 'me', 'begin', 'by', 'clearing', 'up', 'any', 'possible', 'misconception', 'in', 'your', 'minds', ',', 'wherever', 'you', 'are', '.', 'The', 'collective', 'by', 'which', 'I', 'address', 'you', 'in', 'the', 'title', 'above', 'is', 'neither', 'patronizing', 'nor', 'jocose', 'but', 'an', 'exact', 'industrial', 'term', 'in', 'use', 'among', 'professional', 'thieves', '.', 'It', 'is', ',', 'I', 'am', 'reliably', 'given', 'to', 'understand', ',', 'the', 'technical', 'argot', 'for', 'those', 'who', 'engage', 'in', 'your', 'particular', 'branch', 'of', 'the', 'boost', ';', ';', 'i.e.', ',', 'burglars', 'who', 'rob', 'while', 'the', 'tenants', 'are', 'absent', ',', 'in', 'contrast', 'to', 'hot-slough', 'prowlers', ',', 'those', 'who', 'work', 'while', 'the', 'occupants', 'are', 'home', '.', 'Since']

# %%
"""
Program to find count of all words in a corpus and 
print words having a minimum threshold of occurance
"""
from collections import defaultdict

class WordCounter:
    
    def __init__(self):
        self.words = defaultdict(lambda: 0)
        self.word_tokenizer = RegexpTokenizer(r'\w+')
    
    def count_words(self):
        for file in nltk.corpus.brown.fileids():
            for word in nltk.corpus.brown.words(file):
                # tokenize, remove punctuations.
                word_token = self.word_tokenizer.tokenize(word)
                if word_token:
                    # convert all tokens to lowercase and count frequency
                    self.words[word_token[0].lower()] += 1

    def get_words(self, min_frequency=1):
        word_dict = dict()
        for word, frequency in self.words.items():
            if frequency >= min_frequency:
                word_dict[word] = frequency
        return word_dict
                    
                    
if __name__ == '__main__':
    w = WordCounter()
    w.count_words()
    
    # print sorted output
    print(sorted(w.get_words(min_frequency=3).items(), key=lambda x: x[1], reverse=True))
# Out:
# [('the', 69971), ('of', 36412), ('and', 28870), ('to', 26166), ('a', 23409), ('in', 21353), ('that', 10788), ('is', 10109), ('was', 9815), ('he', 9801), ('for', 9489), ('it', 9085), ('with', 7290), ('as', 7254), ('his', 6996), ('on', 6754), ('be', 6377), ('i', 5919), ('at', 5373), ('by', 5323), ('this', 5146), ('had', 5133), ('not', 4620), ('are', 4394), ('but', 4381), ('from', 4370), ('or', 4206), ('have', 3942), ('they', 3763), ('an', 3748), ('you', 3632), ('which', 3561), ('one', 3476), ('were', 3284), ('all', 3052), ('her', 3036), ('she', 2987), ('we', 2844), ('there', 2844), ('would', 2719), ('their', 2670), ('him', 2619), ('been', 2472), ('has', 2437), ('when', 2331), ('who', 2280), ('will', 2246), ('more', 2225), ('no', 2218), ('if', 2198), ('out', 2133), ('so', 2026), ('what', 1968), ('said', 1961), ('can', 1941), ('up', 1896), ('its', 1858), ('about', 1817), ('into', 1791), ('them', 1790), ('than', 1790), ('only', 1748), ('other', 1713), ('new', 1644), ('some', 1618), ('time
# ...
